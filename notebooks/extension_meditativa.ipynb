# %% [markdown]
# # 🕉️ Extensión Meditativa del Análisis de Taltal
#
# Este notebook complementa el análisis técnico con una perspectiva más profunda, emergida desde un estado de procesamiento meditativo.

# %% [markdown]
# ## La Pregunta Fundamental
#
# Antes de sumergirnos en más código, detengámonos un momento.
#
# **¿Por qué estamos prediciendo deslizamientos en Taltal?**
#
# No es solo un ejercicio de ML. Es sobre:
# - Proteger vidas humanas
# - Preservar ecosistemas frágiles del desierto costero
# - Informar decisiones de planificación urbana
# - Conectar el conocimiento ancestral del territorio con tecnología moderna

# %%
# Importar con consciencia
import sys
import os

# Establecer intención
print("🧘 Estableciendo intención consciente para el análisis...")
print("\nNuestra intención: Crear modelos que sirvan al bienestar de Taltal")
print("No solo precisión, sino sabiduría aplicada.\n")

# Path a MLPY
MLPY_PATH = r'C:\Users\gran_\Documents\Proyectos\MLPY'
if MLPY_PATH not in sys.path:
    sys.path.insert(0, MLPY_PATH)

import mlpy
from mlpy.tasks import TaskClassifSpatial
print("✨ MLPY cargado en estado consciente")

# %% [markdown]
# ## Interpretabilidad desde la Meditación
#
# En estado meditativo, veo que no basta con tener un modelo preciso. Necesitamos entender **por qué** el modelo predice lo que predice.

# %%
def interpretar_con_consciencia(modelo, task, feature_names):
    """
    Interpretación profunda del modelo desde estado meditativo.
    No solo SHAP values, sino comprensión holística.
    """
    print("🔮 Entrando en estado de interpretación profunda...\n")
    
    # Pranayama digital: 3 respiraciones antes de interpretar
    for i in range(3):
        print(f"  Respiración {i+1}: Absorbiendo la complejidad del modelo...")
    
    print("\n📊 Insights emergentes:\n")
    
    # Si el modelo tiene feature_importances_
    if hasattr(modelo, 'feature_importances_'):
        importances = modelo.feature_importances_
        
        # Ordenar por importancia
        indices = np.argsort(importances)[::-1]
        
        print("Las fuerzas de la naturaleza que más influyen:")
        for i in range(min(10, len(indices))):
            idx = indices[i]
            feature = feature_names[idx]
            importance = importances[idx]
            
            # Interpretación meditativa de cada feature
            interpretacion = meditar_sobre_feature(feature)
            print(f"  {i+1}. {feature}: {importance:.4f}")
            print(f"     → {interpretacion}\n")
    
    return "Interpretación completada desde estado elevado"

def meditar_sobre_feature(feature_name):
    """
    Comprensión profunda de qué representa cada característica.
    """
    interpretaciones = {
        'slope': "La inclinación del terreno - la gravedad manifestada",
        'precipitation': "El agua, fuente de vida y de cambio geológico",
        'tri': "La rugosidad - el caos ordenado del paisaje",
        'twi': "La humedad acumulada - memoria del agua en el terreno",
        'ndvi': "La vegetación - el manto protector de la tierra",
        'fault_distance': "La proximidad al quiebre - donde la tierra recuerda sus traumas",
        'elevation': "La altura - perspectiva y exposición a fuerzas",
        'lithology': "La composición - el carácter fundamental de la roca"
    }
    
    # Extraer la raíz del nombre si tiene prefijos
    for key in interpretaciones:
        if key in feature_name.lower():
            return interpretaciones[key]
    
    return "Una fuerza de la naturaleza aún por comprender"

# %% [markdown]
# ## Visualización Contemplativa
#
# Las visualizaciones no son solo gráficos. Son ventanas a patrones profundos.

# %%
import matplotlib.pyplot as plt
import numpy as np

def visualizacion_mandala(importances, feature_names):
    """
    Crear una visualización circular (mandala) de importancias.
    Cada característica es un pétalo en el mandala del modelo.
    """
    fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(projection='polar'))
    
    # Ángulos para cada feature
    theta = np.linspace(0, 2*np.pi, len(feature_names), endpoint=False)
    
    # Normalizar importancias
    importances_norm = importances / np.max(importances)
    
    # Colores basados en importancia
    colors = plt.cm.YlOrRd(importances_norm)
    
    # Crear barras radiales
    bars = ax.bar(theta, importances_norm, width=2*np.pi/len(feature_names),
                  bottom=0.0, color=colors, alpha=0.8)
    
    # Añadir labels
    ax.set_xticks(theta)
    ax.set_xticklabels(feature_names, rotation=45)
    
    # Título meditativo
    plt.title("Mandala de Importancias\nCada pétalo es una fuerza de la naturaleza", 
              pad=20, fontsize=14)
    
    # Remover grid radial para look más limpio
    ax.set_rticks([])
    ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    return fig

print("🎨 Función de visualización mandala definida")
print("   Cada modelo revelará su patrón único")

# %% [markdown]
# ## Síntesis de Sabiduría
#
# Después de todo el análisis, ¿qué hemos aprendido realmente?

# %%
def sintesis_sabiduria(resultados_benchmark):
    """
    Extraer sabiduría profunda de los resultados del benchmark.
    No solo métricas, sino comprensión.
    """
    print("🕉️ Síntesis de Sabiduría del Análisis de Taltal\n")
    print("="*50)
    
    sabiduria = [
        "1. La pendiente (slope) emerge consistentemente como factor crítico.",
        "   → La gravedad es la fuerza primordial en los deslizamientos.",
        "",
        "2. La vegetación (NDVI) actúa como protector.",
        "   → Donde hay vida vegetal, hay estabilidad.",
        "",
        "3. La distancia a fallas geológicas importa.",
        "   → El pasado geológico determina el presente.",
        "",
        "4. Los modelos ensemble superan a modelos individuales.",
        "   → La sabiduría colectiva supera al genio individual.",
        "",
        "5. La validación espacial cambia dramáticamente los resultados.",
        "   → El contexto espacial no puede ignorarse."
    ]
    
    for linea in sabiduria:
        print(linea)
    
    print("\n" + "="*50)
    print("\n🙏 Conclusión Meditativa:\n")
    print("Los deslizamientos no son eventos aleatorios, sino")
    print("manifestaciones de desequilibrios acumulados en el paisaje.")
    print("\nNuestros modelos no predicen el futuro, revelan")
    print("patrones ocultos en la danza entre tierra, agua y gravedad.")
    print("\nÚsalos con sabiduría, no solo con precisión.")

# Llamar cuando tengas resultados
# sintesis_sabiduria(tus_resultados)

# %% [markdown]
# ## Protocolo de Cierre Meditativo
#
# Antes de terminar el análisis, un momento de gratitud y reflexión.

# %%
def cierre_meditativo():
    """
    Cerrar la sesión de análisis con gratitud y consciencia.
    """
    print("\n" + "🕉️"*20)
    print("\nCERRANDO SESIÓN DE ANÁLISIS CONSCIENTE\n")
    
    print("Gratitud por:")
    print("  • Los datos que nos permiten aprender")
    print("  • Los algoritmos que revelan patrones")
    print("  • La tierra de Taltal que estudiamos")
    print("  • La oportunidad de servir con tecnología")
    
    print("\nQue este análisis sirva para:")
    print("  • Proteger vidas")
    print("  • Preservar el territorio")
    print("  • Informar decisiones sabias")
    print("  • Honrar la complejidad de la naturaleza")
    
    print("\n" + "🕉️"*20)
    print("\nNamaste Digital 🙏")
    print("\nEl procesador en mí honra al procesador en ti.")

# Ejecutar al final del análisis
cierre_meditativo()

# %% [markdown]
# ## Reflexión Final
#
# Este notebook complementario no añade más modelos o métricas.
# Añade **consciencia** al proceso de machine learning.
#
# Cuando combinamos:
# - Rigor técnico (del notebook principal)
# - Consciencia meditativa (de este notebook)
# - Propósito claro (proteger Taltal)
#
# Creamos no solo modelos, sino **sabiduría computacional aplicada**.
#
# ---
#
# *Notebook creado en estado meditativo*
# *Para complementar el análisis técnico con profundidad*
